# %%
import labtools as lt 
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt 
from matplotlib import cm
import os
from labtools import scanner
import seaborn as sns
from scipy.optimize import curve_fit
from scipy.signal import find_peaks
from labtools import plot_style

# %%
folder = "/home/bbuusshh/my_git/data/fiber/pressure_shift"

# %%
os.listdir(folder)
# Out:
# ['g2_scan_good_0.dump',
#  'g2_scan_good_0.dump_imgs',
#  'g2_1.dump_imgs',
#  'g2_good_0.dump_imgs',
#  'g2_0.dump_imgs',
#  'g2_good_0.dump',
#  'g2_1.dump',
#  'g2_0.dump']

# %%
dmp = "g2_good_0.dump"

# %%
data = np.fromfile(os.path.join(folder, dmp),count=int(1e7), dtype=lt.DUMP_TYPE)

# %%
corr_window = 200_00

# %%
autoc_diffs_tot, autoc_diffs = lt.correlation(data, corr_window=corr_window, start_chs=[3], stop_chs=[4])

# %%
y, x = np.histogram(autoc_diffs_tot, bins=100, range=(-corr_window, corr_window))
plt.plot(x[:-1]/1000, y)
