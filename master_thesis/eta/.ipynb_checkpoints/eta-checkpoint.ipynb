# %%
import numpy as np
from labtools import time_freq_scan as tfs
import labtools as lt
from matplotlib import pyplot as plt
import os
from scipy.signal import find_peaks

from labtools import scanner
from scipy.optimize import curve_fit
from numpy import array
from scipy.cluster.vq import vq, kmeans, whiten
import matplotlib.pyplot as plt

# %%
folder = "/home/bbuusshh/my_git/data/eta"

# %%
os.listdir(folder)
# Out:
# ['pulse_seq_Eta_zoomed_0.dump',
#  'eta_bright_0.dump',
#  'pulse_increase_forEta_2.dump',
#  'eta_betterBtoN_molecule3_0.dump',
#  'eta_bright_withFiberFIlter_0.dump']

# %%
dump = "eta_bright_0.dump"

# %%
data = np.fromfile(os.path.join(folder, dump),count=int(1e7), dtype=lt.DUMP_TYPE)

# %%
len(data)/1e8
# Out:
# 0.1

# %%
data = lt.assign_trigs_to_clicks(data, pix_trigs=[6,7], return_trig=True)
trig = lt.get_trig_len(data)
#data = data[data['channel']!= 5]

# %%
len(data[data['channel']==7])
# Out:
# 48

# %%
len(data[data['channel']==6])
# Out:
# 21225

# %%
line_trig = 7
pix_trig = 6

# %%
d_0 = np.split(data, np.where(data['channel'] == line_trig)[0])
d_lines = np.array(list(map(lambda x: np.split(x, np.where(x['channel'] == pix_trig)[0]), d_0)))

# %%
data = None

# %%
line = d_lines[1]

peak_distance_param=0.25
peak_height_param=0.1
spectr = np.array([len(px) for px in line])

plt.plot(spectr)

# %%
peak_distance_param=0.25
peak_height_param=0.1

peaks, _ = find_peaks(spectr/np.max(spectr), height=peak_height_param, distance=len(spectr)*peak_distance_param)


pk = peaks[spectr[peaks].argmax()]

fr = np.arange(len(spectr))

popt, pcov =curve_fit(scanner.lorentz, fr, spectr, p0=[100,10,pk,100])
perr = np.sqrt(np.diag(pcov)[np.diag(pcov)>0])
tot_err = perr.sum()
pk = int(popt[2])


plt.plot(fr,spectr)
plt.plot(fr[pk], spectr[pk], 'o')

# %%
def get_most_often_linelen(d_lines, clusters=2):
    pxls  = np.array([len(i) for i in d_lines])
    whitened = whiten(pxls)
    centroids, distortion = kmeans(whitened,clusters)
    clx,_ = vq(whitened,centroids)
    clust = np.argmax([len(clx[clx==c]) for c in np.unique(clx)])
    lines_pxs = np.mean(pxls[clx == clust]).astype(int)
    return lines_pxs, pxls, clx,clust, distortion

# %%
lines_pxs, pxls, clx,clust, distortion = get_most_often_linelen(d_lines, clusters=4)
plt.plot(pxls, 'o')
plt.plot(lines_pxs, 'ro')

# %%
pxls  = np.array([len(i) for i in d_lines[clx==clust]])
pxls
# Out:
# array([458, 459, 458, 461, 458, 459, 460, 459, 457, 460, 458, 458, 459,
#        460, 461, 461, 458, 460, 461, 461, 458, 461, 460, 457, 459, 461,
#        460, 459, 460, 461, 459, 460, 459, 460, 458, 458])

# %%
d_lines = np.array(d_lines)[clx==clust]

# %%
px_min = min(np.array([len(i) for i in d_lines]))
px_min
# Out:
# 457

# %%
px_max = max(np.array([len(i) for i in d_lines]))
px_max
# Out:
# 461

# %% [markdown]
# We constrain line pixel len by line_x[0:px_min-1], as the scan return tim eis for some mystical reason variable

# %% [markdown]
# ## Align!

# %%
incRand = np.random.random_integers(0, len(d_lines) - 1,size=10)

# %%
popt, pcov =curve_fit(scanner.lorentz, fr, spectr, p0=[100,10,pk,100])
perr = np.sqrt(np.diag(pcov)[np.diag(pcov)>0])
tot_err = perr.sum()
pk = int(popt[2])

# %%
incRand = np.random.random_integers(0, len(d_lines) - 1,size=20)
t = [int(px[0]['time']) - int(d_lines[0][0][0]['time']) for px in d_lines[0]]
center = (int(d_lines[0][-1][0]['time']) - int(d_lines[0][0][0]['time']))/2
center

peak_distance_param=0.25
peak_height_param=0.1

shifts = []
for line in np.array(d_lines):
    line = line[:px_min]
    t = [int(px[0]['time']) - int(line[0][0]['time']) for px in line]
    spectr = np.array([len(px) for px in line])
    peaks, _ = find_peaks(spectr/np.max(spectr), height=peak_height_param, distance=len(spectr)*peak_distance_param)
    if len(peaks)*len(spectr) == 0:
        print('cont')
        continue
        
    pk = peaks[spectr[peaks].argmax()]
    fr = np.arange(len(spectr))
    try:
        popt, pcov =curve_fit(scanner.lorentz, fr, spectr, p0=[100,10,pk,100])
        perr = np.sqrt(np.diag(pcov)[np.diag(pcov)>0])
        tot_err = perr.sum()
        pk = int(popt[2])
    except:
        print("skip")
        continue
        
    sh = t[pk]
    #plt.plot(fr,spectr)
    #plt.plot(fr[pk], spectr[pk], 'o')
    shift = sh - center
    shifts.append(shift)
    #print(sh)
    line[0]['time'] = line[0]['time'] + shift
    #line = [px['time'] + shift for px in line]

# %%
data2 = np.concatenate(np.concatenate(d_lines))
data2 = data2[np.argsort(data2['time'])]

d_0 = np.split(data2, np.where(data2['channel'] == line_trig)[0])
d_lines = np.array(list(map(lambda x: np.split(x, np.where(x['channel'] == pix_trig)[0]), d_0)))

lines_pxs, pxls, clx,clust, distortion = get_most_often_linelen(d_lines, clusters=4)
d_lines = np.array(d_lines)[clx==clust]
px_min = min(np.array([len(i) for i in d_lines]))
px_min

plt.plot(pxls, 'o')
plt.plot(lines_pxs, 'ro')

# %%
binNum = 1000

# %%
img = np.zeros((px_min, binNum))
for line_x in d_lines[1:]:
    line = np.zeros(binNum)
    for px in line_x[0:px_min-1]:
        y,x = np.histogram(px['time_from_trig'], bins=binNum, range=(10, trig))
        line = np.vstack((line, y))
    img = np.dstack((img, line))

# %%
plt.figure(figsize=(10, 8))
plt.imshow(img.sum(axis=1).T, aspect='auto')

# %%
plt.figure(figsize=(10, 8))
plt.imshow(img[:,220:250,:].sum(axis=2).T, aspect='auto')

# %%
center
# Out:
# 228452469225.5

# %%
line_len = lt.get_trig_len(data2, trig_ch=7)
px_len = lt.get_trig_len(data2, trig_ch=6)

# %%
time_from_start = (data2['time'] - data2['time'][0]).astype(int)

o_range = (center - 100*px_len, center + 100*px_len)

o_range = ((time_from_start % line_len) > o_range[0]) & ((time_from_start % line_len) < o_range[1])

t = np.arange(len((time_from_start % line_len)))

time_scan = (time_from_start % line_len)

# plt.plot(t, time_scan)
# plt.plot(t[o_range], time_scan[o_range], 'o')

# %%
data_0 = data2[o_range | (data2['channel']==5)]

# %%
data_0 = data_0[((data_0['time_from_trig'] > 5.91e6)*(data_0['time_from_trig'] < 6.65e6))  | (data_0['channel']==5)]

# %%
y, x = np.histogram(data_0['time_from_trig'], bins=1000, range=(5.7e6, trig))
plt.plot(x[:-1], y)

# %%
window = (6.65e6 - 5.91e6)//15
M = 3
dms = np.zeros(M)
for i in range(15):
    data_w = data_0[((data_0['time_from_trig'] > 5.91e6)*(data_0['time_from_trig'] < 6.65e6 - i*window))  | (data_0['channel']==5)]
    dat_trig = np.split(data_w, np.where(data_w['channel'] == 5)[0])
    dm = []
    for m in range(1, M+1):
        d = np.concatenate(list(filter(lambda x: (len(x[x['channel'] != 5]) == m), dat_trig)))
        d = np.reshape(d, (int(len(d)/(m+1)), m+1))[:,1:]
        dm.append(d)
    dm_lengs = np.array([len(d) for d in dm])
    dms = np.vstack((dms, dm_lengs))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-d430597010dc> in <module>
#       7     dm = []
#       8     for m in range(1, M+1):
# ----> 9         d = np.concatenate(list(filter(lambda x: (len(x[x['channel'] != 5]) == m), dat_trig)))
#      10         d = np.reshape(d, (int(len(d)/(m+1)), m+1))[:,1:]
#      11         dm.append(d)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: need at least one array to concatenate

# %%
dms = np.flip(dms, axis=0)
dms
# Out:
# array([[4.4130e+03, 1.3900e+02, 4.0000e+00],
#        [6.5340e+03, 3.5600e+02, 1.4000e+01],
#        [8.5150e+03, 6.2000e+02, 3.2000e+01],
#        [1.0316e+04, 9.3900e+02, 6.5000e+01],
#        [1.2040e+04, 1.3410e+03, 1.0100e+02],
#        [1.3620e+04, 1.7600e+03, 1.5300e+02],
#        [1.5044e+04, 2.1970e+03, 2.1800e+02],
#        [1.6318e+04, 2.6850e+03, 3.0500e+02],
#        [1.7486e+04, 3.2140e+03, 4.0300e+02],
#        [1.8614e+04, 3.7320e+03, 5.3100e+02],
#        [1.9676e+04, 4.2820e+03, 6.5600e+02],
#        [2.0581e+04, 4.8280e+03, 8.2500e+02],
#        [2.1379e+04, 5.3980e+03, 9.5800e+02],
#        [2.2146e+04, 5.9700e+03, 1.1290e+03],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00]])

# %%
plt.plot(dms[:-1, 0], 'o')
plt.plot(dms[:-1, 1], 'o')
plt.plot(dms[:-1, 2], 'o')

# %%
dat_trig = np.split(data_0, np.where(data_0['channel'] == 5)[0])

# %%
M = 5
dm = []
for m in range(1, M+1):
    d = np.concatenate(list(filter(lambda x: (len(x[x['channel'] != 5]) == m), dat_trig)))
    d = np.reshape(d, (int(len(d)/(m+1)), m+1))[:,1:]
    dm.append(d)

# %%
Dm_lens = [len(d) for d in dm]

# %%
plt.plot(range(1, M+1), Dm_lens/np.max(Dm_lens))
plt.savefig('offCentre_far.png')

# %%
center
# Out:
# 228452469225.5

# %%
(center - 900*px_len)
# Out:
# 3983835268.3571167

# %%
time_from_start = (data2['time'] - data2['time'][0]).astype(int)

o_range = (center - 900*px_len, center - 700*px_len)

o_range = ((time_from_start % line_len) > o_range[0]) & ((time_from_start % line_len) < o_range[1])

t = np.arange(len((time_from_start % line_len)))

time_scan = (time_from_start % line_len)

# plt.plot(t, time_scan)
# plt.plot(t[o_range], time_scan[o_range], 'o')

data_0 = data2[o_range | (data2['channel']==5)]
data_0 = data_0[(data_0['time_from_trig'] > 0)  | (data_0['channel']==5)]
data_0 = data_0[(data_0['time_from_trig'] > 5.7e6)  | (data_0['channel']==5)]
dat_trig = np.split(data_0, np.where(data_0['channel'] == 5)[0])
M = 5
dm_2 = []
for m in range(1, M+1):
    d = np.concatenate(list(filter(lambda x: (len(x[x['channel'] != 5]) == m), dat_trig)))
    d = np.reshape(d, (int(len(d)/(m+1)), m+1))[:,1:]
    dm_2.append(d)
Dm_lens_2 = [len(d) for d in dm_2]

# %%
plt.plot(range(1, M+1), Dm_lens/np.max(Dm_lens))
plt.plot(range(1, M+1), Dm_lens_2/np.max(Dm_lens_2))

# %%
for d in dm:
    y, x = np.histogram(d['time_from_trig'], bins=1000, range=(5.7e6, trig))
    plt.plot(x[:-1], y)

# %%
corr_window = 600_00000

# %%
autoc_diffs_tot, autoc_diffs = lt.correlation(data_0, corr_window=corr_window, start_chs=[3], stop_chs=[4])

# %%
y, x = np.histogram(autoc_diffs_tot, bins=200, range=(-100000, 100000))
plt.plot(x[:-1]/1000, y)

# %%
# y, x = np.histogram(autoc_diffs, bins=200, range=(-100000, 100000))
# plt.plot(x[:-1]/1000, y)

# %%
for k in autoc_diffs[::2]:
    y, x = np.histogram(k, bins=1000, range=(0, corr_window))
    plt.plot(x[:-1], y)

# %%
import seaborn as sns
sns.set_theme(style="white")
