# %%
import numpy as np
import labtools
from matplotlib import pyplot as plt
import pandas as pd


tt = np.genfromtxt('iv_curve_test__elec.txt')

i = tt[:,0]
v = tt[:,1]

plt.plot(i, v)
plt.ylabel('current, A')
plt.xlabel('voltage, V')
plt.savefig('iv_curve_test__elec.png', dpi=300)
# Out:
# In /home/cryo/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /home/cryo/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /home/cryo/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.

# %%
import numpy as np
import labtools
from matplotlib import pyplot as plt
import pandas as pd


tt = np.genfromtxt('iv_curve_cryo_0to15_new.txt')

i = tt[:,0]
v = tt[:,1]

plt.plot(i, v)
plt.ylabel('current, A')
plt.xlabel('voltage, V')
plt.savefig('iv_curve_cryo_0to15_new.png', dpi=300)

# %%
import numpy as np
import labtools
from matplotlib import pyplot as plt
import pandas as pd


tt = np.genfromtxt('iv_curve_cryo_-60to25_new.txt')

i = -tt[:,0]
v = -tt[:,1]

plt.plot(i, v)
tt_back = np.genfromtxt('iv_curve_cryo60to-40_backpropnew.txt')

i_bck = -tt_back[:,0]
v_bck = -tt_back[:,1]

plt.plot(i_bck, v_bck)
plt.ylabel('current, A')
plt.xlabel('voltage, V')
plt.savefig('iv_curve_cryo_-60to25_new.png', dpi=30)

# %%
iv_curve_cryo60to-40_backpropnew

# %%
import time
import numpy as np 
from matplotlib import pyplot as plt
from  keithley2600 import Keithley2600, ResultTable

# %%
k = Keithley2600('ASRL/dev/ttyUSB0::INSTR')

# %%
k.read_termination = '\r\n'
k.write_termination = '\r\n'
# create ResultTable with two columns
rt = ResultTable(column_titles=['Voltage', 'Current'], units=['V', 'A'],
                 params={'recorded': time.asctime(), 'sweep_type': 'iv'})

# %%
k.applyVoltage(k.smua, 2)
# Out:
# ---------------------------------------------------------------------------
# KeithleyIOError                           Traceback (most recent call last)
# <ipython-input-8-6312feffe5ce> in <module>
# ----> 1 k.applyVoltage(k.smua, 2)
#
# ~/.local/lib/python3.6/site-packages/keithley2600/keithley_driver.py in applyVoltage(self, smu, voltage)
#     682         self._check_smu(smu)
#     683
# --> 684         smu.source.levelv = voltage
#     685         smu.source.func = smu.OUTPUT_DCVOLTS
#     686         smu.source.output = smu.OUTPUT_ON
#
# ~/.local/lib/python3.6/site-packages/keithley2600/keithley_driver.py in __setattr__(self, attr_name, value)
#     236         if attr_name in PROPERTIES:
#     237             value = self._convert_input(value)
# --> 238             self._write('%s.%s = %s' % (self._name, attr_name, value))
#     239         elif attr_name in CONSTANTS:
#     240             raise ValueError('%s.%s is read-only.' % (self._name, attr_name))
#
# ...

# %%
for v in range(-7, 0):
    k.applyVoltage(k.smua, v)
    i = k.smua.measure.i()
    rt.append_row([v, i])
k.smua.source.levelv = 0
# save the data
rt.save('iv_curve_.txt')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/serial/serialposix.py in write(self, data)
#     536             try:
# --> 537                 n = os.write(self.fd, d)
#     538                 if timeout.is_non_blocking:
#
# OSError: [Errno 5] Input/output error
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# <ipython-input-80-7f8c91247afe> in <module>
#       1 for v in range(-7, 0):
# ----> 2     k.applyVoltage(k.smua, v)
#       3     i = k.smua.measure.i()
#       4     rt.append_row([v, i])
#       5 k.smua.source.levelv = 0
#
# ~/.local/lib/python3.6/site-packages/keithley2600/keithley_driver.py in applyVoltage(self, smu, voltage)
#     682         self._check_smu(smu)
#     683
# --> 684         smu.source.levelv = voltage
# ...

# %%
iv_curve_test__piece_desath0

# %%
name='iv_curve_test__piece_desath0'
tt = np.genfromtxt(f'{name}.txt')

i = tt[:,0]
v = tt[:,1]

plt.plot(i, v, 'o')
plt.ylabel('current, A')
plt.xlabel('voltage, V')
plt.savefig(f'{name}.png', dpi=300)

# %%
name='iv_curve_test_0'
tt = np.genfromtxt(f'{name}.txt')

i = tt[:,0]
v = tt[:,1]

plt.plot(i, v, 'o')
plt.ylabel('current, A')
plt.xlabel('voltage, V')
plt.savefig(f'{name}.png', dpi=300)

# %%
tt = np.genfromtxt('iv_curve_cryo_1_K.txt')

i = tt[:,0]
v = tt[:,1]

# %%
plt.plot(i, v, 'o')
plt.ylabel('current, A')
plt.xlabel('voltage, V')
plt.savefig('iv_curve_cryo_1_K.png', dpi=300)

# %%
k.applyVoltage(k.smua, -7)
i = k.smua.measure.i()
i
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/serial/serialposix.py in write(self, data)
#     536             try:
# --> 537                 n = os.write(self.fd, d)
#     538                 if timeout.is_non_blocking:
#
# OSError: [Errno 5] Input/output error
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# <ipython-input-85-ea24c5922917> in <module>
# ----> 1 k.applyVoltage(k.smua, -7)
#       2 i = k.smua.measure.i()
#       3 i
#
# ~/.local/lib/python3.6/site-packages/keithley2600/keithley_driver.py in applyVoltage(self, smu, voltage)
#     682         self._check_smu(smu)
#     683
# --> 684         smu.source.levelv = voltage
#     685         smu.source.func = smu.OUTPUT_DCVOLTS
# ...

# %%
import pandas as pd

# %%
times = ['12:30', '12:40', '13:07', '14:02', '14:48', '15:40', '16:15', '17:10', '17:50']

# %%
procs = [77, 75.5, 70.8, 61.7, 55.6, 44.5, 39.5, 30.2, 23.5]

# %%
timess = np.array([(np.datetime64(f"2015-07-04 {i}") - np.datetime64(f"2015-07-04 {times[0]}")).item().total_seconds()/3600 for i in times])

# %%
plt.plot(timess, procs, 'o')
plt.ylabel('Percent of helium in the reservoir')
plt.xlabel('Time, hours')
plt.savefig('cryo.pdf')

# %%
a= np.datetime64(f"2015-07-04 01:10")

# %%
33/(35/3.5)
# Out:
# 3.3

# %% [markdown]
# ## SiC curve final

# %%
import numpy as np
import labtools
from matplotlib import pyplot as plt
import pandas as pd


tt = np.genfromtxt('iv_curve_cryo-55to60_forwardpropnew.txt')

i = -tt[:,0]
v = -tt[:,1]

plt.plot(i, v)
tt_back = np.genfromtxt('iv_curve_cryo-55to60_nowrealbackpropnew.txt')

i_bck = -tt_back[:,0]
v_bck = -tt_back[:,1]

plt.plot(i_bck, v_bck)
plt.ylabel('current, A')
plt.xlabel('voltage, V')
plt.savefig('iv_curve_cryo-55to60.png', dpi=30)

# %%
tt = np.genfromtxt('iv_curve_cryo_warmer.txt')

i = -tt[:,0]
v = -tt[:,1]

plt.plot(i, v)
